# %% [markdown]
# # Import and read the dataset

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:/Users/Vijay Muthyalu/Pictures/agentz/flights.csv",low_memory=False)

# %%
df
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %% [markdown]
# # Analyzing the data

# %%
df.shape
# Out:
# (5819079, 31)

# %%
##Since the dataset is huge  we can scale it to 20000 rows to avoid huge computation
df=df.loc[0:20001,:]

# %%
##check for datatypes
df.dtypes
# Out:
# YEAR                     int64
# MONTH                    int64
# DAY                      int64
# DAY_OF_WEEK              int64
# AIRLINE                 object
# FLIGHT_NUMBER            int64
# TAIL_NUMBER             object
# ORIGIN_AIRPORT          object
# DESTINATION_AIRPORT     object
# SCHEDULED_DEPARTURE      int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE                 int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL        int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED                 int64
# CANCELLED                int64
# CANCELLATION_REASON     object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# ...

# %%
###check for missing values
df.isnull().sum()
# Out:
# YEAR                       0
# MONTH                      0
# DAY                        0
# DAY_OF_WEEK                0
# AIRLINE                    0
# FLIGHT_NUMBER              0
# TAIL_NUMBER               25
# ORIGIN_AIRPORT             0
# DESTINATION_AIRPORT        0
# SCHEDULED_DEPARTURE        0
# DEPARTURE_TIME           554
# DEPARTURE_DELAY          554
# TAXI_OUT                 559
# WHEELS_OFF               559
# SCHEDULED_TIME             0
# ELAPSED_TIME             591
# AIR_TIME                 591
# DISTANCE                   0
# WHEELS_ON                569
# TAXI_IN                  569
# SCHEDULED_ARRIVAL          0
# ARRIVAL_TIME             569
# ARRIVAL_DELAY            591
# DIVERTED                   0
# CANCELLED                  0
# CANCELLATION_REASON    19440
# AIR_SYSTEM_DELAY       15923
# SECURITY_DELAY         15923
# AIRLINE_DELAY          15923
# LATE_AIRCRAFT_DELAY    15923
# WEATHER_DELAY          15923
# dtype: int64

# %% [markdown]
# # Feature Selection

# %%
df.head(20)
# Out:
#     YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0   2015      1    1            4      AS             98      N407AS
# 1   2015      1    1            4      AA           2336      N3KUAA
# 2   2015      1    1            4      US            840      N171US
# 3   2015      1    1            4      AA            258      N3HYAA
# 4   2015      1    1            4      AS            135      N527AS
# 5   2015      1    1            4      DL            806      N3730B
# 6   2015      1    1            4      NK            612      N635NK
# 7   2015      1    1            4      US           2013      N584UW
# 8   2015      1    1            4      AA           1112      N3LAAA
# 9   2015      1    1            4      DL           1173      N826DN
# 10  2015      1    1            4      DL           2336      N958DN
# 11  2015      1    1            4      AA           1674      N853AA
# 12  2015      1    1            4      DL           1434      N547US
# ...

# %%
#Remove features with more than 50% missing values
missingvalue_df=pd.DataFrame({'columns':df.columns,'count':df.isnull().sum(),'percentage':df.isnull().sum()/df.shape[0]*100})
missingvalue_df.sort_values(by='percentage',ascending=False)
# Out:
#                                  columns  count  percentage
# CANCELLATION_REASON  CANCELLATION_REASON  19440   97.190281
# WEATHER_DELAY              WEATHER_DELAY  15923   79.607039
# LATE_AIRCRAFT_DELAY  LATE_AIRCRAFT_DELAY  15923   79.607039
# AIRLINE_DELAY              AIRLINE_DELAY  15923   79.607039
# SECURITY_DELAY            SECURITY_DELAY  15923   79.607039
# AIR_SYSTEM_DELAY        AIR_SYSTEM_DELAY  15923   79.607039
# AIR_TIME                        AIR_TIME    591    2.954705
# ARRIVAL_DELAY              ARRIVAL_DELAY    591    2.954705
# ELAPSED_TIME                ELAPSED_TIME    591    2.954705
# WHEELS_ON                      WHEELS_ON    569    2.844716
# TAXI_IN                          TAXI_IN    569    2.844716
# ARRIVAL_TIME                ARRIVAL_TIME    569    2.844716
# TAXI_OUT                        TAXI_OUT    559    2.794721
# WHEELS_OFF                    WHEELS_OFF    559    2.794721
# DEPARTURE_DELAY          DEPARTURE_DELAY    554    2.769723
# ...

# %%
cols_to_drop=list(missingvalue_df[missingvalue_df['percentage']>50]['columns'])
cols_to_drop
# Out:
# ['CANCELLATION_REASON',
#  'AIR_SYSTEM_DELAY',
#  'SECURITY_DELAY',
#  'AIRLINE_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  'WEATHER_DELAY']

# %%
df.drop(columns=cols_to_drop,inplace=True)

# %%
###Removing the useless features
df.drop(columns=['FLIGHT_NUMBER','TAIL_NUMBER','WHEELS_OFF','WHEELS_ON','TAXI_IN','TAXI_OUT'],inplace=True)

# %%
##here our output variable is departure delay.We are converting into 1  or o i.e., if values are <0  output is o and >0 then 1

df["OUTPUT_LABEL"]=(df.DEPARTURE_DELAY >=0).astype("int64")
df.OUTPUT_LABEL.value_counts()
df.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'ORIGIN_AIRPORT',
#        'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME',
#        'DEPARTURE_DELAY', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME',
#        'DISTANCE', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'ARRIVAL_DELAY',
#        'DIVERTED', 'CANCELLED', 'OUTPUT_LABEL'],
#       dtype='object')

# %%
df.drop(columns=['DEPARTURE_DELAY'],inplace=True)

# %%
df.OUTPUT_LABEL.value_counts()
# Out:
# 0    10796
# 1     9206
# Name: OUTPUT_LABEL, dtype: int64

# %%
df=df.dropna(axis=0)

# %%
###finally our data is clean
df.isnull().sum()
# Out:
# YEAR                   0
# MONTH                  0
# DAY                    0
# DAY_OF_WEEK            0
# AIRLINE                0
# ORIGIN_AIRPORT         0
# DESTINATION_AIRPORT    0
# SCHEDULED_DEPARTURE    0
# DEPARTURE_TIME         0
# SCHEDULED_TIME         0
# ELAPSED_TIME           0
# AIR_TIME               0
# DISTANCE               0
# SCHEDULED_ARRIVAL      0
# ARRIVAL_TIME           0
# ARRIVAL_DELAY          0
# DIVERTED               0
# CANCELLED              0
# OUTPUT_LABEL           0
# dtype: int64

# %%
###merging airlines code with airlines names from other dataset for data visualization
df_airlines = pd.read_csv('C:/Users/Vijay Muthyalu/Pictures/agentz/airlines.csv')
df_airlines
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
# joining airlines
df = df.merge(df_airlines, left_on='AIRLINE', right_on='IATA_CODE', how='inner')

# %%
df = df.drop(['AIRLINE_x','IATA_CODE'], axis=1)
df = df.rename(columns={"AIRLINE_y":"AIRLINE"})

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
fig_dim = (8,12)
f, ax = plt.subplots(figsize=fig_dim)
quality=df["AIRLINE"].unique()
size=df["AIRLINE"].value_counts()

plt.pie(size,labels=quality,autopct='%1.0f%%')
plt.show()

# %%
import seaborn as sns
sns.set(style="whitegrid")

# initialize the figure
fig_dim = (10,12)
f, ax = plt.subplots(figsize=fig_dim)
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="ARRIVAL_DELAY", y="AIRLINE",
              data=df, dodge=True, jitter=True
            )
plt.show()

# %%
figsize=plt.subplots(figsize=(10,12))
sns.countplot(x='OUTPUT_LABEL',hue='AIRLINE',data=df)
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
df.loc[:5, ['SCHEDULED_DEPARTURE', 'SCHEDULED_ARRIVAL', 'DEPARTURE_TIME',
             'ARRIVAL_TIME', 'ARRIVAL_DELAY']]
# Out:
#    SCHEDULED_DEPARTURE  SCHEDULED_ARRIVAL  DEPARTURE_TIME  ARRIVAL_TIME  \
# 0                    5                430          2354.0         408.0
# 1                   25                320            24.0         259.0
# 2                   45                509            41.0         455.0
# 3                   50                525            46.0         507.0
# 4                  115                548           107.0         545.0
# 5                  155                633           140.0         558.0
#
#    ARRIVAL_DELAY
# 0          -22.0
# 1          -21.0
# 2          -14.0
# 3          -18.0
# 4           -3.0
# 5          -35.0

# %%
##converting to float to int64
df['DEPARTURE_TIME']=df['DEPARTURE_TIME'].astype('int64')
df['ARRIVAL_TIME']=df['ARRIVAL_TIME'].astype('int64')

# %%
##all the above variables contain values from 0 to 2359 represnting military times.
## we use binng method.here we divide each number in the columns by 100 and rounded down to nearest integer. ex:1030 would 
## become 10, 1925 would become 19 and so on and would be left with a maximum of 24 discrete values in this columns.

## this is because probably it doesn't matter much whether a flight departs at 10.30am or 10.40 am.It matters a great deal whether 
## whether it leaves at 10.30am or 5.30 pm

import math 
for index,row in df.iterrows():
    df.loc[index,'SCHEDULED_ARRIVAL']=math.floor(row['SCHEDULED_ARRIVAL']/100)
    df.loc[index,'SCHEDULED_DEPARTURE']=math.floor(row['SCHEDULED_DEPARTURE']/100)
    df.loc[index,'DEPARTURE_TIME']=math.floor(row['DEPARTURE_TIME']/100)
    df.loc[index,'ARRIVAL_TIME']=math.floor(row['ARRIVAL_TIME']/100)
    



df.head(100)
# Out:
#     YEAR  MONTH  DAY  DAY_OF_WEEK ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0   2015      1    1            4            ANC                 SEA
# 1   2015      1    1            4            SEA                 ANC
# 2   2015      1    1            4            ANC                 SEA
# 3   2015      1    1            4            ANC                 PDX
# 4   2015      1    1            4            FAI                 SEA
# ..   ...    ...  ...          ...            ...                 ...
# 95  2015      1    1            4            HNL                 SEA
# 96  2015      1    1            4            SEA                 ORD
# 97  2015      1    1            4            SEA                 TPA
# 98  2015      1    1            4            SEA                 PHL
# 99  2015      1    1            4            SLC                 SAN
#
#     SCHEDULED_DEPARTURE  DEPARTURE_TIME  SCHEDULED_TIME  ELAPSED_TIME  \
# ...

# %%
df['SCHEDULED_TIME']=df['SCHEDULED_TIME'].astype('int64')
df['ELAPSED_TIME']=df['ELAPSED_TIME'].astype('int64')
df['AIR_TIME']=df['AIR_TIME'].astype('int64')

# %%
for index,row in df.iterrows():
    df.loc[index,'SCHEDULED_TIME']=math.floor(row['SCHEDULED_TIME']/100)
    df.loc[index,'ELAPSED_TIME']=math.floor(row['ELAPSED_TIME']/100)
    df.loc[index,'AIR_TIME']=math.floor(row['AIR_TIME']/100)

# %%
y=df['OUTPUT_LABEL']
df.drop(columns=['OUTPUT_LABEL'],inplace=True)

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(df,y,test_size=0.2,random_state=43)

# %%
numerical=df[['DISTANCE','ARRIVAL_DELAY']]

# %%
###  scaling the features 
from sklearn.preprocessing import MinMaxScaler
import numpy as np

scaler=MinMaxScaler()
for col in numerical:
    X_train[col]=scaler.fit_transform(np.array(X_train[col]).reshape(-1,1))
    X_test[col]=scaler.transform(np.array(X_test[col]).reshape(-1,1))
X_test
# Out:
#        YEAR  MONTH  DAY  DAY_OF_WEEK ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 3046   2015      1    1            4            CLT                 LGA
# 5282   2015      1    1            4            HSV                 ATL
# 16214  2015      1    1            4            BWI                 LIT
# 4226   2015      1    1            4            RSW                 DTW
# 16388  2015      1    1            4            OMA                 MDW
# ...     ...    ...  ...          ...            ...                 ...
# 7718   2015      1    1            4            EWR                 LAX
# 7379   2015      1    1            4            IAH                 CLE
# 15744  2015      1    1            4            SJC                 SAN
# 870    2015      1    1            4            LAX                 KOA
# 5955   2015      1    2            5            JAX                 MSP
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  SCHEDULED_TIME  ELAPSED_TIME  \
# ...

# %%
categorical=df[['AIRLINE','ORIGIN_AIRPORT','DESTINATION_AIRPORT']]
categorical
# Out:
#                     AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT
# 0      Alaska Airlines Inc.            ANC                 SEA
# 1      Alaska Airlines Inc.            SEA                 ANC
# 2      Alaska Airlines Inc.            ANC                 SEA
# 3      Alaska Airlines Inc.            ANC                 PDX
# 4      Alaska Airlines Inc.            FAI                 SEA
# ...                     ...            ...                 ...
# 19406        Virgin America            SFO                 AUS
# 19407        Virgin America            LAX                 JFK
# 19408        Virgin America            DAL                 LGA
# 19409        Virgin America            SEA                 LAX
# 19410        Virgin America            SFO                 LAX
#
# [19411 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np


class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)

# %%
##converting strings to numbers
from sklearn.preprocessing import LabelEncoder

le=LabelEncoderExt()

for col in categorical:
    le.fit(X_train[col])
    X_train[col]=le.transform(X_train[col])
    X_test[col]=le.transform(X_test[col])

# %%
X_train
# Out:
#        YEAR  MONTH  DAY  DAY_OF_WEEK  ORIGIN_AIRPORT  DESTINATION_AIRPORT  \
# 15403  2015      1    1            4             268                  209
# 10320  2015      1    1            4             267                   49
# 7917   2015      1    1            4             213                   34
# 5739   2015      1    2            5             210                   17
# 11831  2015      1    2            5             260                  241
# ...     ...    ...  ...          ...             ...                  ...
# 5307   2015      1    1            4              17                  186
# 18448  2015      1    1            4             213                  285
# 7985   2015      1    1            4             260                  210
# 18687  2015      1    1            4             272                   78
# 14148  2015      1    1            4             251                   17
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  SCHEDULED_TIME  ELAPSED_TIME  \
# ...

# %%
from sklearn.linear_model import LogisticRegression

logreg=LogisticRegression()

logreg.fit(X_train,y_train)



y_pred=logreg.predict(X_test)
comparisons_df=pd.DataFrame({'Actuals':y_test,'Predictions':y_pred})
comparisons_df
# Out:
#        Actuals  Predictions
# 3046         0            1
# 5282         0            0
# 16214        1            1
# 4226         0            0
# 16388        1            1
# ...        ...          ...
# 7718         1            1
# 7379         1            1
# 15744        1            0
# 870          0            1
# 5955         0            0
#
# [3883 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score,f1_score,roc_curve
confusion_matrix(y_test,y_pred)
print("logistic regression:")
print("accuracy:",accuracy_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
# Out:
# logistic regression:
# accuracy: 0.6425444244141127
# recall: 0.5434537246049661
# precision: 0.6245136186770428

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree.fit(X_train,y_train)
tree_predict=tree.predict(X_test)

# %%
confusion_matrix(y_test,tree_predict)
print('accuarcy_score',accuracy_score(y_test,tree_predict))
print('recall',recall_score(y_test,tree_predict))

print('precision:',precision_score(y_test,tree_predict))
# Out:
# accuarcy_score 0.6999742467164564
# recall 0.6800225733634312
# precision: 0.6683305601774819

# %%
print(" Decision tree classifier")
print('train score :---',tree.score(X_train,y_train))
print('test score:---',tree.score(X_test,y_test))
# Out:
#  Decision tree classifier
# train score :--- 1.0
# test score:--- 0.7038372392480041

# %%
from sklearn.ensemble import RandomForestClassifier
random=RandomForestClassifier()
random.fit(X_train,y_train)
random_predict=tree.predict(X_test)

# %%
print('accuarcy_score',accuracy_score(y_test,random_predict))
print('recall',recall_score(y_test,random_predict))

print('precision:',precision_score(y_test,random_predict))
# Out:
# accuarcy_score 0.6999742467164564
# recall 0.6800225733634312
# precision: 0.6683305601774819

# %%
from sklearn.ensemble import AdaBoostClassifier
ada=AdaBoostClassifier()
ada.fit(X_train,y_train)
predict1=ada.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score,f1_score,roc_curve
confusion_matrix(y_test,y_pred)
print("accuracy:",accuracy_score(y_test,predict1))
print("recall:",recall_score(y_test,predict1))
print("precision:",precision_score(y_test,predict1))
# Out:
# accuracy: 0.7700231779551893
# recall: 0.6884875846501128
# precision: 0.7815502882767457

# %%
print(" ADA Boosting")
print('train score :---',ada.score(X_train,y_train))
print('test score:---',ada.score(X_test,y_test))

# %%
from sklearn.ensemble import GradientBoostingClassifier
gradient=GradientBoostingClassifier()
gradient.fit(X_train,y_train)
predict=gradient.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score,f1_score,roc_curve,roc_auc_score
confusion_matrix(y_test,y_pred)
print("GradientBoosting")
print("accuracy:",accuracy_score(y_test,predict))
print("recall:",recall_score(y_test,predict))
print("precision:",precision_score(y_test,predict))
# Out:
# GradientBoosting
# accuracy: 0.7816121555498327
# recall: 0.7054176072234764
# precision: 0.7931472081218274

# %%
print(" Gradient Boosting")
print('train score :---',gradient.score(X_train,y_train))
print('test score:---',gradient.score(X_test,y_test))
# Out:
#  Gradient Boosting
# train score :--- 0.7940494590417311
# test score:--- 0.7816121555498327

# %%
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
y_pred_prob=gradient.predict_proba(X_test)[::,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob) #the function roc_curve returns three values,the false positives
                                                #threshold values it used to calculate the tpr and fpr
auc = roc_auc_score(y_test,y_pred_prob)    
plt.plot(fpr,tpr,label="auc"+str(auc))
plt.xlabel('false positive rate')
plt.ylabel('True POSITIVE RATE')
plt.title('AOC-ROC curve')
plt.legend(loc=5)
plt.show()

# %%
results = pd.DataFrame({
    'Model': ['LogisticRegression', 'Random Forest','Adaboosting', 'Gradient boosting'],
    'Score': [accuracy_score(y_test,y_pred), accuracy_score(y_test,random_predict),accuracy_score(y_test,predict1), 
              accuracy_score(y_test,predict)]})
    
result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Model')
result_df
# Out:
#                        Score
# Model
# Gradient boosting   0.781612
# Adaboosting         0.770023
# Random Forest       0.699974
# LogisticRegression  0.642544

# %% [markdown]
# # Final Conclusion

# %%
Gradient Boosting performed well with an accuaracy of 78% and auc-roc score of 86%
